# %%
import sys
import warnings
sys.path.extend(['/home/abd/blah/lib/python3.6/site-packages'])
from datetime import datetime

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn
# %matplotlib inline

# %%
data=pd.read_csv('data/london-outcomes.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1947050 entries, 0 to 1947049
# Data columns (total 10 columns):
# Crime ID        object
# Month           object
# Reported by     object
# Falls within    object
# Longitude       float64
# Latitude        float64
# Location        object
# LSOA code       object
# LSOA name       object
# Outcome type    object
# dtypes: float64(2), object(8)
# memory usage: 148.5+ MB

# %%
len(data)
# Out:
# 1947050

# %%
data =data.drop(['Crime ID'], axis=1)

# %%
data=data.drop(['Crime ID','Month', 'Longitude', 'Latitude', 'LSOA code'], axis=1)

# %%
data=data.dropna()

# %%
len(data)
# Out:
# 1915110

# %%
len(set(data['LSOA name']))
# Out:
# 5713

# %%
len(set(data['Outcome type']))
# Out:
# 23

# %%
# Out:
#                          Reported by                 Falls within  \
# 1              City of London Police        City of London Police
# 2              City of London Police        City of London Police
# 3              City of London Police        City of London Police
# 4              City of London Police        City of London Police
# 5              City of London Police        City of London Police
# 7              City of London Police        City of London Police
# 8              City of London Police        City of London Police
# 9              City of London Police        City of London Police
# 10             City of London Police        City of London Police
# 11             City of London Police        City of London Police
# 12             City of London Police        City of London Police
# 13             City of London Police        City of London Police
# 14             City of London Police        City of London Police
# ...
